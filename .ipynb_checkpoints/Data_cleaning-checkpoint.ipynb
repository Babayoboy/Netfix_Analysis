# %%
import pandas as pd
import numpy as np
df = pd.read_csv("dataset/Netfix_analysis.csv")

# %%
df.head(5)
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# 2           6.3                en                            Thriller
# 3           7.7                en  Animation, Comedy, Family, Fantasy
# 4           7.0                en    Action, Adventure, Thriller, War
#
#                                           Poster_Url
# 0  https://image.tmdb.org/t/p/original/1g0dhYtq4i...
# 1  https://image.tmdb.org/t/p/original/74xTEgt7R3...
# 2  https://image.tmdb.org/t/p/original/vDHsLnOWKl...
# 3  https://image.tmdb.org/t/p/original/4j0PNHkMr5...
# 4  https://image.tmdb.org/t/p/original/aq4Pwv5Xeu...

# %%
df = df.drop(columns=['Overview','Poster_Url'])

# %%
df.isnull().sum()
# Out:
# Release_Date         0
# Title                0
# Popularity           0
# Vote_Count           0
# Vote_Average         0
# Original_Language    0
# Genre                0
# Action               0
# Adventure            0
# Animation            0
# Comedy               0
# Crime                0
# Documentary          0
# Drama                0
# Family               0
# Fantasy              0
# History              0
# Horror               0
# Music                0
# Mystery              0
# Romance              0
# Science Fiction      0
# TV Movie             0
# Thriller             0
# War                  0
# Western              0
# dtype: int64

# %%
df.groupby("Genre").count()
# Out:
#                                               Release_Date  Title  Popularity  \
# Genre
# Action                                                  99     99          99
# Action, Adventure                                       24     24          24
# Action, Adventure, Animation                             6      6           6
# Action, Adventure, Animation, Comedy                     1      1           1
# Action, Adventure, Animation, Comedy, Family             3      3           3
# ...                                                    ...    ...         ...
# Western, Drama, Mystery                                  1      1           1
# Western, History                                         1      1           1
# Western, Horror                                          2      2           2
# Western, Mystery, Thriller, Drama                        1      1           1
# Western, Thriller                                        2      2           2
#
#                                               Vote_Count  Vote_Average  \
# Genre
# Action                                                99            99
# Action, Adventure                                     24            24
# Action, Adventure, Animation                           6             6
# Action, Adventure, Animation, Comedy                   1             1
# Action, Adventure, Animation, Comedy, Family           3             3
# ...                                                  ...           ...
# Western, Drama, Mystery                                1             1
# Western, History                                       1             1
# Western, Horror                                        2             2
# Western, Mystery, Thriller, Drama                      1             1
# Western, Thriller                                      2             2
#
#                                               Original_Language  Action  \
# Genre
# Action                                                       99      99
# Action, Adventure                                            24      24
# Action, Adventure, Animation                                  6       6
# Action, Adventure, Animation, Comedy                          1       1
# Action, Adventure, Animation, Comedy, Family                  3       3
# ...                                                         ...     ...
# Western, Drama, Mystery                                       1       1
# Western, History                                              1       1
# Western, Horror                                               2       2
# Western, Mystery, Thriller, Drama                             1       1
# Western, Thriller                                             2       2
#
#                                               Adventure  Animation  Comedy  \
# Genre
# Action                                               99         99      99
# Action, Adventure                                    24         24      24
# Action, Adventure, Animation                          6          6       6
# Action, Adventure, Animation, Comedy                  1          1       1
# Action, Adventure, Animation, Comedy, Family          3          3       3
# ...                                                 ...        ...     ...
# Western, Drama, Mystery                               1          1       1
# Western, History                                      1          1       1
# Western, Horror                                       2          2       2
# Western, Mystery, Thriller, Drama                     1          1       1
# Western, Thriller                                     2          2       2
#
#                                               ...  History  Horror  Music  \
# Genre                                         ...
# Action                                        ...       99      99     99
# Action, Adventure                             ...       24      24     24
# Action, Adventure, Animation                  ...        6       6      6
# Action, Adventure, Animation, Comedy          ...        1       1      1
# Action, Adventure, Animation, Comedy, Family  ...        3       3      3
# ...                                           ...      ...     ...    ...
# Western, Drama, Mystery                       ...        1       1      1
# Western, History                              ...        1       1      1
# Western, Horror                               ...        2       2      2
# Western, Mystery, Thriller, Drama             ...        1       1      1
# Western, Thriller                             ...        2       2      2
#
#                                               Mystery  Romance  \
# Genre
# Action                                             99       99
# Action, Adventure                                  24       24
# Action, Adventure, Animation                        6        6
# Action, Adventure, Animation, Comedy                1        1
# Action, Adventure, Animation, Comedy, Family        3        3
# ...                                               ...      ...
# Western, Drama, Mystery                             1        1
# Western, History                                    1        1
# Western, Horror                                     2        2
# Western, Mystery, Thriller, Drama                   1        1
# Western, Thriller                                   2        2
#
#                                               Science Fiction  TV Movie  \
# Genre
# Action                                                     99        99
# Action, Adventure                                          24        24
# Action, Adventure, Animation                                6         6
# Action, Adventure, Animation, Comedy                        1         1
# Action, Adventure, Animation, Comedy, Family                3         3
# ...                                                       ...       ...
# Western, Drama, Mystery                                     1         1
# Western, History                                            1         1
# Western, Horror                                             2         2
# Western, Mystery, Thriller, Drama                           1         1
# Western, Thriller                                           2         2
#
#                                               Thriller  War  Western
# Genre
# Action                                              99   99       99
# Action, Adventure                                   24   24       24
# Action, Adventure, Animation                         6    6        6
# Action, Adventure, Animation, Comedy                 1    1        1
# Action, Adventure, Animation, Comedy, Family         3    3        3
# ...                                                ...  ...      ...
# Western, Drama, Mystery                              1    1        1
# Western, History                                     1    1        1
# Western, Horror                                      2    2        2
# Western, Mystery, Thriller, Drama                    1    1        1
# Western, Thriller                                    2    2        2
#
# [2337 rows x 25 columns]

# %%
unique_genres = sorted(
    list(
        set(
            [
                g.strip()
                for sublist in df["Genre"].dropna().str.split(",")
                for g in sublist
            ]
        )
    )
)

print(f"Found {len(unique_genres)} unique genres in the file:")
print(unique_genres)

# 3. Create a brand new column for every discovered genre
for genre in unique_genres:
    # Checks if the text exists in the row's Genre entry
    df[genre] = np.where(
        df["Genre"].str.contains(genre, case=False, na=False), "Yes", "No"
    )
# Out:
# Found 19 unique genres in the file:
# ['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction', 'TV Movie', 'Thriller', 'War', 'Western']

# %%
df.head(3)
# Out:
#   Release_Date                    Title  Popularity  Vote_Count  Vote_Average  \
# 0   2021-12-15  Spider-Man: No Way Home    5083.954        8940           8.3
# 1   2022-03-01               The Batman    3827.658        1151           8.1
# 2   2022-02-25                  No Exit    2618.087         122           6.3
#
#   Original_Language                               Genre Action Adventure  \
# 0                en  Action, Adventure, Science Fiction    Yes       Yes
# 1                en            Crime, Mystery, Thriller     No        No
# 2                en                            Thriller     No        No
#
#   Animation  ... History Horror Music Mystery Romance Science Fiction  \
# 0        No  ...      No     No    No      No      No             Yes
# 1        No  ...      No     No    No     Yes      No              No
# 2        No  ...      No     No    No      No      No              No
#
#   TV Movie Thriller War Western
# 0       No       No  No      No
# 1       No      Yes  No      No
# 2       No      Yes  No      No
#
# [3 rows x 26 columns]
